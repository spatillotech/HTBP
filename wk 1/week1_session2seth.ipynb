# %% [markdown]
# # Week 1, Session 2: Data Types & Operations
#
# **Date:** ___________
# **Student Name:** ___________
#
# ## Learning Objectives
# - Understand different data types (str, int, float, bool)
# - Use `type()` to check variable types
# - Master string methods and slicing
# - Perform arithmetic operations
# - Understand operator precedence (PEMDAS)
#
# ---

# %% [markdown]
# ## Part 1: Quick Review
#
# Let's quickly review what we learned in Session 1:

# %%
# Variables and print()
name = "thes"
print("Welcome back,brudda", name)

# String concatenation
greeting = "Hello" + ", hello " + "World!"
print(greeting)
# Out:
# Welcome back,brudda thes
# Hello, hello World!

# %% [markdown]
# ---
# ## Part 2: Data Types - What Kind of Data is This?
#
# In Python, every value has a **type**. The type determines what you can do with that value.
#
# ### The Four Basic Data Types:
#
# 1. **`str` (String)** - Text data
# 2. **`int` (Integer)** - Whole numbers
# 3. **`float` (Floating-point)** - Decimal numbers
# 4. **`bool` (Boolean)** - True or False values

# %% [markdown]
# ### Strings (str) - Text Data

# %%
# Strings are always in quotes
name = "Alice"
message = 'Hello, World!'
address = "123 Main Street"

# Check the type using type()
print(type(name))
print(type(message))
print(type(address))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ### Integers (int) - Whole Numbers

# %%
# Integers are whole numbers (no decimal point)
age = 25
year = 2024
temperature = -5
count = 0

# find the type for the variables: age, year, and temperature
print(type(age)) # follow the pattern and fill in the blank with the code to find the type
print(type(year))
print(type(count))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### Floats (float) - Decimal Numbers

# %%
# Floats have decimal points
price = 19.99
gpa = 3.75
pi = 3.14159
temperature = 98.6

print(type(price))
print(type(gpa))
print(type(pi))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ### Booleans (bool) - True or False

# %%
# Booleans represent truth values
# Note: Must be capitalized! True and False, not true and false
is_student = True
is_raining = False
has_license = True

print(type(is_student))
print(is_raining)
# Out:
# <class 'bool'>
# False

# %% [markdown]
# ### ⚠️ Important: Types Matter!

# %%
# Look at these carefully - they're different!
age_number = 25        # This is an integer
age_string = "25"      # This is a string

print(type(age_number))
print(type(age_string))

# They look the same when printed, but they're different types!
print(age_number)
print(age_string)

# %% [markdown]
# ### ✏️ Your Turn!
# Create variables of each type and check their types:

# %%
# Create a string variable
my_string = "seth"

# Create an integer variable
my_integer = 19

# Create a float variable
my_float = 1.9

# Create a boolean variable
my_boolean = True

# Print the types of each
print(type(my_string))
print(type(my_integer))
print(type(my_float))
print(type(my_boolean))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ---
# ## Part 3: String Methods - Powerful Tools for Text
#
# Strings have built-in **methods** - special functions that work on strings. You call them using a dot (`.`) after the string.

# %% [markdown]
# ### `.upper()` and `.lower()` - Change Case

# %%
text = "Hello, Python!"

# Convert to uppercase
print(text.upper())      # HELLO, PYTHON!

# Convert to lowercase
print(text.lower())      # hello, python!

# Original text is unchanged
print(text)              # Hello, Python!
# Out:
# HELLO, PYTHON!
# hello, python!
# Hello, Python!

# %%
# Useful for making comparisons case-insensitive
user_input = "YES"

# Convert to lowercase to make comparison easier
if user_input.lower() == "yes":
    print("User said yes!")

# %% [markdown]
# ### `.strip()` - Remove Whitespace

# %%
# Remove spaces from the beginning and end
messy = "   Hello, World!   "
clean = messy.strip()

print("Before:", messy)      # "   Hello, World!   "
print("After:", clean)        # "Hello, World!"

# Very useful for cleaning user input!

# %% [markdown]
# ### `.replace()` - Replace Parts of a String

# %%
# Replace one substring with another
sentence = "I love Python programming"

# Replace "Python" with "JavaScript"
new_sentence = sentence.replace("Python", "JavaScript")
print(new_sentence)  # I love JavaScript programming

# Replace spaces with underscores
with_underscores = sentence.replace(" ", "_")
print(with_underscores)  # I_love_Python_programming

# %% [markdown]
# ### Other Useful String Methods

# %%
text = "python is awesome"

# Capitalize first letter
print(text.capitalize())   # Python is awesome

# Title case (capitalize each word)
print(text.title())        # Python Is Awesome

# Count occurrences of a substring
print(text.count("o"))     # 2 (there are 2 'o's)

# Find position of substring
print(text.find("is"))     # 7 ("is" starts at position 7)

# Check if string starts with something
print(text.startswith("py"))  # True

# Check if string ends with something
print(text.endswith("me"))    # True
# Out:
# Python is awesome
# Python Is Awesome
# 2
# 7
# True
# True

# %% [markdown]
# ### ✏️ Your Turn!
# Practice string methods:

# %%
# Create a string with your full name
full_name = "seth patillo"

# Print it in all uppercase
print(full_name.upper())

# Print it in all lowercase
print(full_name.lower())

# Replace your first name with "Dr."
print(full_name.replace ("seth", "dr."))

# Count how many vowels (a, e, i, o, u) are in your name (you'll need multiple .count() calls)
print(full_name.count("a"))
print(full_name.count("e"))
print(full_name.count("i"))
print(full_name.count("o"))
print(full_name.count("u"))
# Out:
# SETH PATILLO
# seth patillo
# dr. patillo
# 1
# 1
# 1
# 1
# 0

# %% [markdown]
# ---
# ## Part 4: String Slicing - Extracting Parts of Strings
#
# You can access individual characters or ranges of characters using **slicing**.
#
# **Syntax:** `string[start:end]`
# - `start` is inclusive (included)
# - `end` is exclusive (not included)
# - Indexing starts at 0!

# %%
# String indexing
word = "Python"
#       012345  <- positions (indices)

# Access individual characters
print(word[0])
print(word[1])
print(word[5])
# Out:
# P
# y
# n

# %%
# Negative indices count from the end
word = "Python"
#      -6-5-4-3-2-1  <- negative positions

print(word[-1])
print(word[-2])
print(word[-6])
# Out:
# n
# o
# P

# %%
# Slicing - getting a range of characters
word = "Python"

# Get first 3 characters
print(word[0:3])

# Get characters from position 2 to 5
print(word[2:5])

# Omit start to begin from the beginning
print(word[:3])

# Omit end to go to the end
print(word[2:])

# Get everything
print(word[:])
# Out:
# Pyt
# tho
# Pyt
# thon
# Python

# %%
# Practical examples
email = "student@university.edu"

# Extract username (everything before @)
at_position = email.find("@")
username = email[:at_position]
print("Username:", username)  # student

# Extract domain (everything after @)
domain = email[at_position + 1:]
print("Domain:", domain)      # university.edu

# %%
# Step slicing - every nth character
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# Every other letter
print(alphabet[::2])   # ACEGIKMOQSUWY

# Reverse a string!
print(alphabet[::-1])  # ZYXWVUTSRQPONMLKJIHGFEDCBA
# Out:
# ACEGIKMOQSUWY
# ZYXWVUTSRQPONMLKJIHGFEDCBA

# %% [markdown]
# ### ✏️ Your Turn!
# Practice string slicing:

# %%
# Use this string for practice
phrase = "Hello World Python"

# Get the first word
print(phrase[:5])

# Get the last word
print(phrase[6:11])
# Get "World"
print(phrase[6:11])
# Reverse the entire string
print
# Out:
# Hello
# World

# %% [markdown]
# ---
# ## Part 5: Arithmetic Operations - Math in Python
#
# Python can perform all basic math operations. It's like a powerful calculator!

# %% [markdown]
# ### Basic Arithmetic Operators

# %%
# Addition
result = 10 + 5
print("10 + 5 =", result)

# Subtraction
result = 10 - 5
print("10 - 5 =", result)

# Multiplication
result = 10 * 5
print("10 * 5 =", result)

# Division (always returns a float)
result = 10 / 5
print("10 / 5 =", result)
print(type(result))
# Out:
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0
# <class 'float'>

# %% [markdown]
# ### Special Division Operators

# %%
# Floor division - divides and rounds down to nearest integer
result = 10 // 3
print("10 // 3 =", result)     # 3 (not 3.333...)

# Modulus - gives the remainder after division
result = 10 % 3
print("10 % 3 =", result)      # 1 (because 10 ÷ 3 = 3 remainder 1)

# Exponentiation - raising to a power
result = 2 ** 8
print("2 ** 8 =", result)      # 256 (2 to the power of 8)
# Out:
# 10 // 3 = 3
# 10 % 3 = 1
# 2 ** 8 = 256

# %% [markdown]
# ### Practical Uses of Modulus (%)

# %%
# Check if a number is even or odd
number = 17
remainder = number % 2
print(f"{number} % 2 = {remainder}")
# If remainder is 0, number is even
# If remainder is 1, number is odd

# Check if a number is divisible by another
number = 15
if number % 5 == 0:
    print(f"{number} is divisible by 5")
# Out:
# 17 % 2 = 1
# 15 is divisible by 5

# %% [markdown]
# ### Operator Precedence - PEMDAS
#
# Python follows the same order of operations you learned in math class:
#
# 1. **P**arentheses `()`
# 2. **E**xponents `**`
# 3. **M**ultiplication and **D**ivision `*`, `/`, `//`, `%` (left to right)
# 4. **A**ddition and **S**ubtraction `+`, `-` (left to right)

# %%
# Example 1: Multiplication before addition
result = 2 + 3 * 4
print(result)  # 14, not 20
# Calculation: 3 * 4 = 12, then 2 + 12 = 14 using pemdas

# Use parentheses to change order
result = (2 + 3) * 4
print(result)  # 20
# Calculation: 2 + 3 = 5, then 5 * 4 = 20

# %%
# Example 2: Multiple operations
result = 10 + 2 * 5 ** 2 / 4 - 3
print(result)
# Step by step:
# No parentheses so we move to exponentiation: ** ⬇️
# 5 ** 2 = 25 ---> exponentiation
# 2 * 25 = 50 ---> multiplication
# 50 / 4 = 12.5 ---> division
# 10 + 12.5 = 22.5 ---> addition
# 22.5 - 3 = 19.5 ----> subtraction

# %%
# Best practice: Use parentheses for clarity!
# Even if not strictly necessary, they make code easier to read

price = ___ # put a random number here between 50 and 100
quantity = ___ # put a random number here between 2 and 10
tax = ___ # put a random number here between 10 and 30

# Unclear:
total = price * quantity + tax
print('Total is: ', total)

# Clear:
total = (price * quantity) + tax
print('Total is: ', total)

# %% [markdown]
# ### Working with Variables in Calculations

# %%
# Calculate area of a rectangle
length = 10
width = 5
area = length * width
print("Area:", area)  # 50

# Calculate circle area
radius = 7
pi = 3.14159
area = pi * radius ** 2
print("Circle area:", area)  # 153.93804

# Calculate compound interest
principal = 1000
rate = 0.05  # 5%
time = 3     # years
amount = principal * (1 + rate) ** time
print("Amount after 3 years: $", amount)
# Out:
# Area: 50
# Circle area: 153.93791
# Amount after 3 years: $ 1157.6250000000002

# %% [markdown]
# ### ✏️ Your Turn!
# Practice arithmetic operations:

# %%
# 1. Calculate the area of a triangle: (base * height) / 2
base = 10
height = 8
triangle_area = (base * height) / 2
print(type(triangle_area))
print("Triangle area:", result)

# 2. Convert temperature from Fahrenheit to Celsius: (F - 32) * 5/9
fahrenheit = 98.6
celsius = ((fahrenheit) - 32) * 5/9
print("Temperature in Celsius:", result)

# 3. Calculate if a year is a leap year (divisible by 4)
year = 2024
remainder = (year / 4)
print("Remainder when divided by 4:", result)
# If remainder is 0, it's a leap year!

# 4. Calculate your age in days (approximate) converting years to days: Years * 365
age_years = 19
age_days = (age_years * 365)
print("Age in days:", result)
# Out:
# <class 'float'>
# Triangle area: 256
# Temperature in Celsius: 256
# Remainder when divided by 4: 256
# Age in days: 256

# %% [markdown]
# ---
# ## 🧪 LAB 2: Mad Libs & Calculator
#
# Now let's combine everything you've learned today!

# %% [markdown]
# ### Part A: Mad Libs Generator
#
# Create a fun story using variables and string methods.
#
# **Requirements:**
# 1. Create variables for different word types (noun, verb, adjective, place, etc.)
# 2. Use string concatenation to build a story
# 3. Use at least 2 string methods (`.upper()`, `.lower()`, `.title()`, `.replace()`, etc.)
# 4. Make it creative and funny!

# %%
# LAB 2 - Part A: Mad Libs

# Create your variables
noun = "elephant"
verb = "dancing"
adjective = "sparkly"
place = "kitchen"
# Add more variables as needed

# Create your story
# Example template (feel free to make your own!):
# "Once upon a time, in a [adjective] [place], there was a [noun] who loved [verb]..."

# Your story here:


# Use string methods to make it more interesting


# Print your final story

# %% [markdown]
# ### Part B: Basic Calculator
#
# Create a calculator that performs operations on two numbers.
#
# **Requirements:**
# 1. Define two numbers
# 2. Perform ALL arithmetic operations (+, -, *, /, //, %, **)
# 3. Print each result with a descriptive label
# 4. Calculate at least one expression that uses PEMDAS
# 5. Use modulus to check if the first number is divisible by the second

# %%
# LAB 2 - Part B: Calculator

# Define your two numbers
num1 = 69
num2 = 67

print("Calculator for", num1, "and", num2)
print("=" * 30)  # Print a line of equal signs

# Perform all arithmetic operations
# Addition

# Subtraction

# Multiplication

# Division

# Floor Division

# Modulus

# Exponentiation


print("=" * 30)

# PEMDAS calculation
# Example: (num1 + num2) * 3 - num1 ** 2


# Divisibility check
# Is num1 divisible by num2?

# %% [markdown]
# ---
# ## 📝 Reflection Questions

# %% [markdown]
# **Your Answers:**
#
# 1. What's the difference between `int` and `float`? Integers have no .0 and floats have
#
# 2. What does the modulus operator (%) do?
# they can tell you a remainder
# 3. it helps with consistency
#
# 4. What was your favorite string method and why?
# String manipulation, becasue it''s the easiest for me to grasp.

# %% [markdown]
# ---
# ## 📚 WEEKLY ASSIGNMENT 1
#
# **Due: Before Week 2, Session 1**
#
# This assignment covers everything you learned in Week 1. Complete all parts below.
#
# ---

# %% [markdown]
# ### Part 1: Personal Information System
#
# Create a comprehensive program that demonstrates variables, data types, and print statements.
#
# **Requirements:**
# - Create variables for: full name, **fake** age, **fake** email, **fake** phone number, **fake** address, school/company (fake because when you put this on github, it becomes public info)
# - Print them in a nicely formatted way
# - Use appropriate data types for each

# %%
# ASSIGNMENT - Part 1: Personal Information

# Create your variables
name= "Seth Patillo"
age= "42"
email= "realhumanpersondefinitely@notarobot.ai"
address= "1600 Pretzel Welch Way"

# Print formatted output
print(name)
print(age)
print(email)
print(address)
# Out:
# Seth Patillo
# 42
# realhumanpersondefinitely@notarobot.ai
# 1600 Pretzel Welch Way

# %% [markdown]
# ### Part 2: String Manipulation
#
# Take your full name and perform various string operations.
#
# **Requirements:**
# - Print it in all uppercase
# - Print it in all lowercase
# - Print just your first name using slicing
# - Print just your last name using slicing
# - Print your initials using slicing

# %%
# ASSIGNMENT - Part 2: String Manipulation

full_name = "Seth Patillo"  # Your full name here

print(full_name)

# All uppercase
print(full_name.upper())

# All lowercase

print(full_name.lower())
# First name only (using slicing)
print(full_name [:4])

# Last name only (using slicing)

print(full_name[5:12])
# Initials (using slicing)

print(full_name[:1])
print(full_name[5:6])
print("================================")
# Out:
# Seth Patillo
# SETH PATILLO
# seth patillo
# Seth
# Patillo
# S
# P
# ...

# %% [markdown]
# ### Part 3: Bio Generator
#
# Create a short bio using at least 5 variables.
#
# **Requirements:**
# - Use string concatenation
# - Use the `.replace()` method at least once
# - Make it at least 3 sentences long
# - Be creative!

# %%
# ASSIGNMENT - Part 3: Bio Generator

# Create at least 5 variables for your bio
name ="Seth"
hometown ="Houston"
interest ="Biology"
favorite_movie="Star Wars: Revenge Of The Sith"

# Add more...

print("===== MY BIO =====")

# Build your bio using concatenation
bio = "Hi! My name is " + name + " and my hometown is "+ hometown + " my interest is " + interest + " my favorite movie is " + favorite_movie + "."

# Use .replace() to create a variation
new_bio = bio.replace(hometown, "Austin")
print(new_bio)
new_interest = bio.replace(interest, "chess")
print(new_interest)
print("==================")
# Out:
# ===== MY BIO =====
# Hi! My name is Seth and my hometown is Austin my interest is Biology my favorite movie is Star Wars: Revenge Of The Sith.
# Hi! My name is Seth and my hometown is Houston my interest is chess my favorite movie is Star Wars: Revenge Of The Sith.
# ...

# %% [markdown]
# ### Part 4: Number Facts
#
# Work with numbers and perform calculations.
#
# **Requirements:**
# - Calculate your age from birth year and current year
# - Calculate your favorite number squared, cubed, and halved
# - Use modulus to check if your favorite number is even or odd
# - Calculate at least one more interesting fact with numbers

# %%
# ASSIGNMENT - Part 4: Number Facts

birth_year =2006
current_year = 2026
favorite_number =24
my_age = (current_year - birth_year)
print(type(my_age))
print("My age is", my_age)

print("===== NUMBER FACTS =====")

# Calculate age

print("My age is", my_age)

# Favorite number squared
print (favorite_number * favorite_number)

# Favorite number cubed
print (favorite_number * favorite_number * favorite_number)

# Favorite number halved
print (favorite_number / 2)


# Check if even or odd (print the remainder)
if favorite_number % 2 == 1:
  print("odd")
if favorite_number % 2 == 0:
  print("even")
# Your own calculation (be creative!)
numb1 =9
numb2 =10
the_answer = (numb1 + numb2)
print(the_answer)

print("========================")
# Out:
# <class 'int'>
# My age is 20
# ===== NUMBER FACTS =====
# My age is 20
# 576
# 13824
# 12.0
# even
# 19
# ...

# %% [markdown]
# ### Part 5: Code Quality Check
#
# **Before submitting, make sure you have:**
# - [ ] Comments explaining each section
# - [ ] Meaningful variable names (not `x`, `y`, `z`)
# - [ ] Organized code with clear sections
# - [ ] Tested all code (everything runs without errors)
# - [ ] Creative touches that go beyond minimum requirements

# %% [markdown]
# ---
# ## 💾 Submission Instructions
#
# ### How to Submit Your Work:
#
# 1. Click **Save in Github to keep changes**
# 2. **File naming convention:** `week1_session2_yourname.ipynb`
# 3. Add me as a collaborator on your repository. My username is avisink on Github.
#
# **Grading:**
# - Lab 2: 40 points (completion and functionality)
# - Weekly Assignment 1: 60 points (completeness, correctness, creativity)

# %% [markdown]
# ## 🎯 Week 1 Summary
#
# Congratulations! In Week 1, you learned:
#
# ### Session 1:
# - ✅ What Python is and why it's useful
# - ✅ How to use Google Colab
# - ✅ `print()` function
# - ✅ Comments with `#`
# - ✅ Variables and naming rules
# - ✅ String basics and concatenation
#
# ### Session 2:
# - ✅ Data types: `str`, `int`, `float`, `bool`
# - ✅ `type()` function
# - ✅ String methods: `.upper()`, `.lower()`, `.strip()`, `.replace()`
# - ✅ String slicing
# - ✅ Arithmetic operations: `+`, `-`, `*`, `/`, `//`, `%`, `**`
# - ✅ Operator precedence (PEMDAS)
#
# **Next Week Preview:**
# - Getting user input with `input()`
# - Type conversion
# - Making decisions with `if`/`elif`/`else`
# - Boolean logic
#
# **Keep practicing and see you in Week 2! 🚀**
